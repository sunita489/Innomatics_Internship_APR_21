# %%
#Question 1
import cmath
x = input()
print(abs(complex(x)))
print(cmath.phase(complex(x)))

# %%
#Question 2
import math
ab = int(input())
bc = int(input())
res = ab / bc
angle = math.degrees(math.atan(res))
print(str(round(angle)) + chr(176),sep='')

# %%
#Question 3
for i in range(1,int(input())+1):
    print (((10**i - 1)//9)**2)

# %%
#Question 4
a = int(input())
b = int(input())
print(a//b)
print(a%b)
print(divmod(a,b))

# %%
#Question 5
a = int(input())
b = int(input())
m = int(input())
print(a**b)
print(pow(a,b,m))

# %%
#Question 6
a = int(input())
b = int(input())
c = int(input())
d = int(input())
print((a**b)+(c**d))

# %%
#Question 7
for i in range(1,int(input())):
    print((10**i//9)*i)
